# %% [markdown]
# ### 1. Import all required python library
# ### 2. Load the Dataset into pandas’ data frame.
# ### 3. Data Preprocessing: check for missing values in the data using pandas isnull (),
# ### Types of variables etc. Check the dimensions of the data frame.
# ### 4. Data Formatting and Data Normalization: Summarize the types of variables by checking the
# ### data types (i.e., character, numeric, integer, factor, and logical) of the variables in the data set. If
# ### variables are not in the correct data type, apply proper type conversions.

# %%
import numpy as np
import pandas as pd
from sklearn import preprocessing

# %%
df = pd.read_csv("Placement_Data_Full_Class.csv")

# %%
df
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p
# 0        1      M  67.00   Others  91.00   Others  Commerce     58.00  \
# 1        2      M  79.33  Central  78.33   Others   Science     77.48
# 2        3      M  65.00  Central  68.00  Central      Arts     64.00
# 3        4      M  56.00  Central  52.00  Central   Science     52.00
# 4        5      M  85.80  Central  73.60  Central  Commerce     73.30
# ..     ...    ...    ...      ...    ...      ...       ...       ...
# 210    211      M  80.60   Others  82.00   Others  Commerce     77.60
# 211    212      M  58.00   Others  60.00   Others   Science     72.00
# 212    213      M  67.00   Others  67.00   Others  Commerce     73.00
# 213    214      F  74.00   Others  66.00   Others  Commerce     58.00
# 214    215      M  62.00  Central  58.00   Others   Science     53.00
#
#       degree_t workex  etest_p specialisation  mba_p      status    salary
# ...

# %%
df.isna().sum()
# Out:
# sl_no              0
# gender             0
# ssc_p              0
# ssc_b              0
# hsc_p              0
# hsc_b              0
# hsc_s              0
# degree_p           0
# degree_t           0
# workex             0
# etest_p            0
# specialisation     0
# mba_p              0
# status             0
# salary            67
# dtype: int64

# %%
df.dtypes
# Out:
# sl_no               int64
# gender             object
# ssc_p             float64
# ssc_b              object
# hsc_p             float64
# hsc_b              object
# hsc_s              object
# degree_p          float64
# degree_t           object
# workex             object
# etest_p           float64
# specialisation     object
# mba_p             float64
# status             object
# salary            float64
# dtype: object

# %%
#filling null values
for i in df:
    if(df[i].dtypes == "float64"):
        df[i] = df[i].fillna(df[i].mean())

# %%
df.isna().sum()
# Out:
# sl_no             0
# gender            0
# ssc_p             0
# ssc_b             0
# hsc_p             0
# hsc_b             0
# hsc_s             0
# degree_p          0
# degree_t          0
# workex            0
# etest_p           0
# specialisation    0
# mba_p             0
# status            0
# salary            0
# dtype: int64

# %%
df.dtypes
# Out:
# sl_no               int64
# gender             object
# ssc_p             float64
# ssc_b              object
# hsc_p             float64
# hsc_b              object
# hsc_s              object
# degree_p          float64
# degree_t           object
# workex             object
# etest_p           float64
# specialisation     object
# mba_p             float64
# status             object
# salary            float64
# dtype: object

# %%
df
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p
# 0        1      M  67.00   Others  91.00   Others  Commerce     58.00  \
# 1        2      M  79.33  Central  78.33   Others   Science     77.48
# 2        3      M  65.00  Central  68.00  Central      Arts     64.00
# 3        4      M  56.00  Central  52.00  Central   Science     52.00
# 4        5      M  85.80  Central  73.60  Central  Commerce     73.30
# ..     ...    ...    ...      ...    ...      ...       ...       ...
# 210    211      M  80.60   Others  82.00   Others  Commerce     77.60
# 211    212      M  58.00   Others  60.00   Others   Science     72.00
# 212    213      M  67.00   Others  67.00   Others  Commerce     73.00
# 213    214      F  74.00   Others  66.00   Others  Commerce     58.00
# 214    215      M  62.00  Central  58.00   Others   Science     53.00
#
#       degree_t workex  etest_p specialisation  mba_p      status
# ...

# %%
##qualitative to quantitative
labelencoder = preprocessing.LabelEncoder()
for i in df:
    if(df[i].dtypes == "object"):
        df[i] = labelencoder.fit_transform(df[i])

# %%
df
# Out:
#      sl_no  gender  ssc_p  ssc_b  hsc_p  hsc_b  hsc_s  degree_p  degree_t
# 0        1       1  67.00      1  91.00      1      1     58.00         2  \
# 1        2       1  79.33      0  78.33      1      2     77.48         2
# 2        3       1  65.00      0  68.00      0      0     64.00         0
# 3        4       1  56.00      0  52.00      0      2     52.00         2
# 4        5       1  85.80      0  73.60      0      1     73.30         0
# ..     ...     ...    ...    ...    ...    ...    ...       ...       ...
# 210    211       1  80.60      1  82.00      1      1     77.60         0
# 211    212       1  58.00      1  60.00      1      2     72.00         2
# 212    213       1  67.00      1  67.00      1      1     73.00         0
# 213    214       0  74.00      1  66.00      1      1     58.00         0
# 214    215       1  62.00      0  58.00      1      2     53.00         0
#
#      workex  etest_p  specialisation  mba_p  status         salary
# ...

# %%
df2 = pd.read_csv("Placement_Data_Full_Class.csv")
df2
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p
# 0        1      M  67.00   Others  91.00   Others  Commerce     58.00  \
# 1        2      M  79.33  Central  78.33   Others   Science     77.48
# 2        3      M  65.00  Central  68.00  Central      Arts     64.00
# 3        4      M  56.00  Central  52.00  Central   Science     52.00
# 4        5      M  85.80  Central  73.60  Central  Commerce     73.30
# ..     ...    ...    ...      ...    ...      ...       ...       ...
# 210    211      M  80.60   Others  82.00   Others  Commerce     77.60
# 211    212      M  58.00   Others  60.00   Others   Science     72.00
# 212    213      M  67.00   Others  67.00   Others  Commerce     73.00
# 213    214      F  74.00   Others  66.00   Others  Commerce     58.00
# 214    215      M  62.00  Central  58.00   Others   Science     53.00
#
#       degree_t workex  etest_p specialisation  mba_p      status    salary
# ...

# %%
df2.dtypes
# Out:
# sl_no               int64
# gender             object
# ssc_p             float64
# ssc_b              object
# hsc_p             float64
# hsc_b              object
# hsc_s              object
# degree_p          float64
# degree_t           object
# workex             object
# etest_p           float64
# specialisation     object
# mba_p             float64
# status             object
# salary            float64
# dtype: object

# %%
df2['hsc_b'] = df2['hsc_b'].astype(str)
df2.dtypes
# Out:
# sl_no               int64
# gender             object
# ssc_p             float64
# ssc_b              object
# hsc_p             float64
# hsc_b              object
# hsc_s              object
# degree_p          float64
# degree_t           object
# workex             object
# etest_p           float64
# specialisation     object
# mba_p             float64
# status             object
# salary            float64
# dtype: object

# %%
scaler = preprocessing.MinMaxScaler()

# %%
columns = []
for i in df:
    columns.append(i)
columns
# Out:
# ['sl_no',
#  'gender',
#  'ssc_p',
#  'ssc_b',
#  'hsc_p',
#  'hsc_b',
#  'hsc_s',
#  'degree_p',
#  'degree_t',
#  'workex',
#  'etest_p',
#  'specialisation',
#  'mba_p',
#  'status',
#  'salary']

# %%
df = scaler.fit_transform(df)
df
# Out:
# array([[0.        , 1.        , 0.53823954, ..., 0.28448276, 1.        ,
#         0.09459459],
#        [0.0046729 , 1.        , 0.79241394, ..., 0.56484258, 1.        ,
#         0.        ],
#        [0.00934579, 1.        , 0.49701093, ..., 0.2470015 , 1.        ,
#         0.06756757],
#        ...,
#        [0.99065421, 1.        , 0.53823954, ..., 0.69377811, 1.        ,
#         0.12837838],
#        [0.9953271 , 0.        , 0.68253968, ..., 0.33808096, 1.        ,
#         0.00540541],
#        [1.        , 1.        , 0.43516801, ..., 0.33770615, 0.        ,
#         0.1198046 ]])

# %%
df = pd.DataFrame(df, columns=columns)
df
# Out:
#         sl_no  gender     ssc_p  ssc_b     hsc_p  hsc_b  hsc_s  degree_p
# 0    0.000000     1.0  0.538240    1.0  0.889621    1.0    0.5  0.195122  \
# 1    0.004673     1.0  0.792414    0.0  0.680890    1.0    1.0  0.670244
# 2    0.009346     1.0  0.497011    0.0  0.510708    0.0    0.0  0.341463
# 3    0.014019     1.0  0.311482    0.0  0.247117    0.0    1.0  0.048780
# 4    0.018692     1.0  0.925788    0.0  0.602965    0.0    0.5  0.568293
# ..        ...     ...       ...    ...       ...    ...    ...       ...
# 210  0.981308     1.0  0.818594    1.0  0.741351    1.0    0.5  0.673171
# 211  0.985981     1.0  0.352711    1.0  0.378913    1.0    1.0  0.536585
# 212  0.990654     1.0  0.538240    1.0  0.494234    1.0    0.5  0.560976
# 213  0.995327     0.0  0.682540    1.0  0.477759    1.0    0.5  0.195122
# 214  1.000000     1.0  0.435168    0.0  0.345964    1.0    1.0  0.073171
#
#      degree_t  workex   etest_p  specialisation     mba_p  status    salary
# ...

# %%
df3 = df.copy()
df4 = df.copy()

# %%
#MinMax Normalization (X - min) / (max - min)
for i in df3 :
    df3[i] = (df3[i] - df3[i].min()) / (df3[i].max() - df3[i].min())
df
# Out:
#         sl_no  gender     ssc_p  ssc_b     hsc_p  hsc_b  hsc_s  degree_p
# 0    0.000000     1.0  0.538240    1.0  0.889621    1.0    0.5  0.195122  \
# 1    0.004673     1.0  0.792414    0.0  0.680890    1.0    1.0  0.670244
# 2    0.009346     1.0  0.497011    0.0  0.510708    0.0    0.0  0.341463
# 3    0.014019     1.0  0.311482    0.0  0.247117    0.0    1.0  0.048780
# 4    0.018692     1.0  0.925788    0.0  0.602965    0.0    0.5  0.568293
# ..        ...     ...       ...    ...       ...    ...    ...       ...
# 210  0.981308     1.0  0.818594    1.0  0.741351    1.0    0.5  0.673171
# 211  0.985981     1.0  0.352711    1.0  0.378913    1.0    1.0  0.536585
# 212  0.990654     1.0  0.538240    1.0  0.494234    1.0    0.5  0.560976
# 213  0.995327     0.0  0.682540    1.0  0.477759    1.0    0.5  0.195122
# 214  1.000000     1.0  0.435168    0.0  0.345964    1.0    1.0  0.073171
#
#      degree_t  workex   etest_p  specialisation     mba_p  status    salary
# ...

# %%
#zscore norml : formula : X - mean / std dev
for i in df4:
    df4[i] = df4[i] - df4[i].mean() / df4[i].std()
df4
# Out:
#         sl_no    gender      ssc_p     ssc_b      hsc_p     hsc_b      hsc_s
# 0   -7.763381 -0.476753 -22.961035  0.076842 -45.719189 -0.304218 -10.182414  \
# 1   -7.758708 -0.476753 -22.706860 -0.923158 -45.927920 -0.304218  -9.682414
# 2   -7.754035 -0.476753 -23.002263 -0.923158 -46.098101 -1.304218 -10.682414
# 3   -7.749363 -0.476753 -23.187792 -0.923158 -46.361693 -1.304218  -9.682414
# 4   -7.744690 -0.476753 -22.573486 -0.923158 -46.005844 -1.304218 -10.182414
# ..        ...       ...        ...       ...        ...       ...        ...
# 210 -6.782073 -0.476753 -22.680680  0.076842 -45.867459 -0.304218 -10.182414
# 211 -6.777400 -0.476753 -23.146563  0.076842 -46.229897 -0.304218  -9.682414
# 212 -6.772727 -0.476753 -22.961035  0.076842 -46.114576 -0.304218 -10.182414
# 213 -6.768054 -1.476753 -22.816734  0.076842 -46.131050 -0.304218 -10.182414
# 214 -6.763381 -0.476753 -23.064106 -0.923158 -46.262846 -0.304218  -9.682414
#
# ...
